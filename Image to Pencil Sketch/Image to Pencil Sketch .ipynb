# %% [markdown]
# # NAME : PRIYANK BAGAD

# %% [markdown]
# # TASK 2 : IMAGE TO PENCIL SKETCH
# # DATA SCIENCE INTERNSHIP

# %% [markdown]
# **Importing Libraries**

# %%
from PIL import Image
from IPython.display import display
import cv2

# %% [markdown]
# **Loading the image**

# %%
image = cv2.imread('ganpati.jpg', 1)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=564x705 at 0x4D6F718>

# %% [markdown]
# **Resizing the image**

# %%
image = cv2.resize(image, (400,500))
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=400x500 at 0x4D5FBF8>

# %% [markdown]
# **Image into RGB**

# %%
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
display(Image.fromarray(img_rgb))
# Out:
# <PIL.Image.Image image mode=RGB size=400x500 at 0xA8F7B20>

# %% [markdown]
# **Image into greyscale**

# %%
img_grey = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(img_grey))
# Out:
# <PIL.Image.Image image mode=L size=400x500 at 0xCA50FA0>

# %% [markdown]
# **Greyscale to inverted image**

# %%
img_inv = cv2.bitwise_not(img_grey)
display(Image.fromarray(img_inv))
# Out:
# <PIL.Image.Image image mode=L size=400x500 at 0x6158250>

# %% [markdown]
# **Smoothness**

# %%
img_smooth = cv2.GaussianBlur(img_inv, (5, 5), 0, 0)
display(Image.fromarray(img_smooth))
# Out:
# <PIL.Image.Image image mode=L size=400x500 at 0x4D6F328>

# %% [markdown]
# **Final Sketch**

# %%
img_smooth_inv = 255 - img_smooth
img_final = cv2.divide(img_grey, img_smooth_inv, scale=256.0)
display(Image.fromarray(img_final))
# Out:
# <PIL.Image.Image image mode=L size=400x500 at 0xCA50EE0>

# %% [markdown]
# # Happy Ganesh Chaturthi <3 !!!
# # Thank-you!
